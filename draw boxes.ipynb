# %%
import cv2
import pandas as pd
from PIL import Image

# %%
full_labels = pd.read_csv('data/cabbage_labels.csv')

# %%
full_labels.head()
# Out:
#       filename  width  height    class  xmin  ymin  xmax  ymax
# 0  pic_108.jpg    259     194  cabbage    62    52   186   160
# 1  pic_047.jpg    259     194  cabbage    46     1   220   170
# 2  pic_015.jpg    220     170  cabbage    49    27   155   125
# 3  pic_045.jpg    255     197  cabbage    29    15   227   167
# 4  pic_018.jpg    136     180  cabbage    70    69   117   128

# %%
def draw_boxes(image_name):
    selected_value = full_labels[full_labels.filename == image_name]
    img = cv2.imread('images/{}'.format(image_name))
    for index, row in selected_value.iterrows():
        img = cv2.rectangle(img, (row['xmin'], row['ymin']), (row['xmax'], row['ymax']), (0, 255, 0), 3)
    return img

# %%
Image.fromarray(draw_boxes('pic_004.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7FEC0961B898>

# %%
Image.fromarray(draw_boxes('pic_086.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7FEC0958B320>

# %%
Image.fromarray(draw_boxes('pic_122.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=266x189 at 0x7FEC0958B470>

# %%
Image.fromarray(draw_boxes('pic_097.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7FEC09597198>

# %%
Image.fromarray(draw_boxes('pic_130.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=207x243 at 0x7FEC095972E8>

# %%
Image.fromarray(draw_boxes('pic_140.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7FEC09597080>

# %%
Image.fromarray(draw_boxes('pic_047.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7FEC09597358>

# %%
Image.fromarray(draw_boxes('pic_054.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=194x259 at 0x7FEC09597160>
